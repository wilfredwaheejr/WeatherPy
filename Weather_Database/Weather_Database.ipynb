# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 755

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c3236ae67f370d8b4590822fc7475efb

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in our list.
for i in range(len(cities)):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + cities[i]
    
# Loop through all the cities in the list.
    for i, city in enumerate(cities):

        # Group cities in sets of 50 for logging purposes.
        if (i % 50 == 0 and i >= 50):
            set_count += 1
            record_count = 1
            time.sleep(60)

        # Create endpoint URL with each city.
        city_url = url + "&q=" + city.replace(" ","+")

        # Log the URL, record, and set numbers and the city.
        print(f"Processing Record {record_count} of Set {set_count} | {city}")
        # Add 1 to the record count.
        record_count += 1
    
# Run an API request for each of the cities.
        try:
            # Parse the JSON and retrieve data.
            city_weather = requests.get(city_url).json()
            # Parse out the needed data.
            city_lat = city_weather["coord"]["lat"]
            city_lng = city_weather["coord"]["lon"]
            city_weather_description = city_weather["weather"][0]["description"]
            city_max_temp = city_weather["main"]["temp_max"]
            city_humidity = city_weather["main"]["humidity"]
            city_clouds = city_weather["clouds"]["all"]
            city_wind = city_weather["wind"]["speed"]
            city_country = city_weather["sys"]["country"]
            # Convert the date to ISO standard.
            city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
            # Append the city information into city_data list.
            city_data.append({"City": city.title(),
                              "Lat": city_lat,
                              "Lng": city_lng,
                              "Description": city_weather_description,
                              "Max Temp": city_max_temp,
                              "Humidity": city_humidity,
                              "Cloudiness": city_clouds,
                              "Wind Speed": city_wind,
                              "Country": city_country,
                              "Date": city_date})

# If an error is experienced, skip the city.
        except:
            print("City not found. Skipping...")
            pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | upernavik
# Processing Record 2 of Set 1 | ushuaia
# Processing Record 3 of Set 1 | nanortalik
# Processing Record 4 of Set 1 | iracoubo
# Processing Record 5 of Set 1 | longyearbyen
# Processing Record 6 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 7 of Set 1 | arzgir
# Processing Record 8 of Set 1 | luba
# Processing Record 9 of Set 1 | tecoanapa
# Processing Record 10 of Set 1 | deputatskiy
# Processing Record 11 of Set 1 | vaini
# Processing Record 12 of Set 1 | tashtagol
# Processing Record 13 of Set 1 | kodiak
# Processing Record 14 of Set 1 | hermanus
# Processing Record 15 of Set 1 | cervenia
# Processing Record 16 of Set 1 | ipueiras
# Processing Record 17 of Set 1 | hilo
# Processing Record 18 of Set 1 | butaritari
# Processing Record 19 of Set 1 | paamiut
# Processing Record 20 of Set 1 | terrace
# Processing Record 21 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 22 of Set 1 | olafsvik
# Processing Record 23 of Set 1 | busselton
# Processing Record 24 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 25 of Set 1 | dharan
# Processing Record 26 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 27 of Set 1 | steinbach
# Processing Record 28 of Set 1 | charcas
# Processing Record 29 of Set 1 | cockburn town
# Processing Record 30 of Set 1 | guangyuan
# Processing Record 31 of Set 1 | puerto ayora
# Processing Record 32 of Set 1 | eureka
# Processing Record 33 of Set 1 | poum
# Processing Record 34 of Set 1 | port alfred
# Processing Record 35 of Set 1 | palmer
# Processing Record 36 of Set 1 | astana
# Processing Record 37 of Set 1 | nakhon thai
# Processing Record 38 of Set 1 | kaitangata
# Processing Record 39 of Set 1 | hithadhoo
# Processing Record 40 of Set 1 | kavaratti
# Processing Record 41 of Set 1 | tezu
# Processing Record 42 of Set 1 | makakilo city
# Processing Record 43 of Set 1 | phalodi
# Processing Record 44 of Set 1 | punta arenas
# Processing Record 45 of Set 1 | avarua
# Processing Record 46 of Set 1 | atuona
# Processing Record 47 of Set 1 | banda aceh
# Processing Record 48 of Set 1 | colotlan
# Processing Record 49 of Set 1 | ulladulla
# Processing Record 50 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 1 of Set 2 | talnakh
# Processing Record 2 of Set 2 | tuktoyaktuk
# Processing Record 3 of Set 2 | salinas
# Processing Record 4 of Set 2 | rikitea
# Processing Record 5 of Set 2 | caravelas
# Processing Record 6 of Set 2 | thompson
# Processing Record 7 of Set 2 | okhotsk
# Processing Record 8 of Set 2 | boyolangu
# Processing Record 9 of Set 2 | nishihara
# Processing Record 10 of Set 2 | nome
# Processing Record 11 of Set 2 | san cristobal
# Processing Record 12 of Set 2 | port lincoln
# Processing Record 13 of Set 2 | mehamn
# Processing Record 14 of Set 2 | mount isa
# Processing Record 15 of Set 2 | tarudant
# City not found. Skipping...
# Processing Record 16 of Set 2 | meulaboh
# Processing Record 17 of Set 2 | albany
# Processing Record 18 of Set 2 | guanica
# Processing Record 19 of Set 2 | meyungs
# City not found. Skipping...
# Processing Record 20 of Set 2 | arraial do cabo
# Processing Record 21 of Set 2 | sitka
# Processing Record 22 of Set 2 | muli
# Processing Record 23 of Set 2 | chuy
# Processing Record 24 of Set 2 | bluff
# Processing Record 25 of Set 2 | sao filipe
# Processing Record 26 of Set 2 | marsa matruh
# Processing Record 27 of Set 2 | tahta
# Processing Record 28 of Set 2 | hobart
# Processing Record 29 of Set 2 | barrow
# Processing Record 30 of Set 2 | hauterive
# Processing Record 31 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 32 of Set 2 | high level
# Processing Record 33 of Set 2 | victoria
# Processing Record 34 of Set 2 | faya
# Processing Record 35 of Set 2 | yantal
# Processing Record 36 of Set 2 | qaanaaq
# Processing Record 37 of Set 2 | bengkulu
# Processing Record 38 of Set 2 | ilulissat
# Processing Record 39 of Set 2 | castro
# Processing Record 40 of Set 2 | qasigiannguit
# Processing Record 41 of Set 2 | jamestown
# Processing Record 42 of Set 2 | agadez
# Processing Record 43 of Set 2 | iqaluit
# Processing Record 44 of Set 2 | anadyr
# Processing Record 45 of Set 2 | safaga
# Processing Record 46 of Set 2 | bredasdorp
# Processing Record 47 of Set 2 | pevek
# Processing Record 48 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 49 of Set 2 | henties bay
# Processing Record 50 of Set 2 | nyimba
# Processing Record 1 of Set 3 | fortuna
# Processing Record 2 of Set 3 | north platte
# Processing Record 3 of Set 3 | carnarvon
# Processing Record 4 of Set 3 | sept-iles
# Processing Record 5 of Set 3 | weligama
# Processing Record 6 of Set 3 | port elizabeth
# Processing Record 7 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 8 of Set 3 | yellowknife
# Processing Record 9 of Set 3 | synya
# Processing Record 10 of Set 3 | kisangani
# Processing Record 11 of Set 3 | bideford
# Processing Record 12 of Set 3 | cidreira
# Processing Record 13 of Set 3 | bonfim
# Processing Record 14 of Set 3 | ribeira grande
# Processing Record 15 of Set 3 | kawalu
# Processing Record 16 of Set 3 | lagoa
# Processing Record 17 of Set 3 | ponta do sol
# Processing Record 18 of Set 3 | codrington
# Processing Record 19 of Set 3 | ishigaki
# Processing Record 20 of Set 3 | ballina
# Processing Record 21 of Set 3 | bethel
# Processing Record 22 of Set 3 | dunedin
# Processing Record 23 of Set 3 | east london
# Processing Record 24 of Set 3 | inhambane
# Processing Record 25 of Set 3 | esperance
# Processing Record 26 of Set 3 | nikolskoye
# Processing Record 27 of Set 3 | altay
# Processing Record 28 of Set 3 | dujuma
# City not found. Skipping...
# Processing Record 29 of Set 3 | kinchil
# Processing Record 30 of Set 3 | kitimat
# Processing Record 31 of Set 3 | naryshkino
# Processing Record 32 of Set 3 | corning
# Processing Record 33 of Set 3 | mataura
# Processing Record 34 of Set 3 | gazipur
# Processing Record 35 of Set 3 | mar del plata
# Processing Record 36 of Set 3 | port shepstone
# Processing Record 37 of Set 3 | ferme-neuve
# Processing Record 38 of Set 3 | namtsy
# Processing Record 39 of Set 3 | clyde river
# Processing Record 40 of Set 3 | itarema
# Processing Record 41 of Set 3 | khatanga
# Processing Record 42 of Set 3 | warqla
# City not found. Skipping...
# Processing Record 43 of Set 3 | torbay
# Processing Record 44 of Set 3 | bereda
# Processing Record 45 of Set 3 | vostok
# Processing Record 46 of Set 3 | srednekolymsk
# Processing Record 47 of Set 3 | labuhan
# Processing Record 48 of Set 3 | alta floresta
# Processing Record 49 of Set 3 | tocopilla
# Processing Record 50 of Set 3 | naze
# Processing Record 1 of Set 4 | hamada
# Processing Record 2 of Set 4 | xixiang
# Processing Record 3 of Set 4 | chiuiesti
# City not found. Skipping...
# Processing Record 4 of Set 4 | nelson bay
# Processing Record 5 of Set 4 | cape town
# Processing Record 6 of Set 4 | bokspits
# City not found. Skipping...
# Processing Record 7 of Set 4 | dikson
# Processing Record 8 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 9 of Set 4 | plettenberg bay
# Processing Record 10 of Set 4 | zeya
# Processing Record 11 of Set 4 | tautira
# Processing Record 12 of Set 4 | airai
# Processing Record 13 of Set 4 | ambon
# Processing Record 14 of Set 4 | northam
# Processing Record 15 of Set 4 | myitkyina
# Processing Record 16 of Set 4 | siena
# Processing Record 17 of Set 4 | dobryanka
# Processing Record 18 of Set 4 | norman wells
# Processing Record 19 of Set 4 | lolua
# City not found. Skipping...
# Processing Record 20 of Set 4 | korla
# Processing Record 21 of Set 4 | luganville
# Processing Record 22 of Set 4 | sadovoye
# Processing Record 23 of Set 4 | kapaa
# Processing Record 24 of Set 4 | karauzyak
# City not found. Skipping...
# Processing Record 25 of Set 4 | viransehir
# Processing Record 26 of Set 4 | ruatoria
# City not found. Skipping...
# Processing Record 27 of Set 4 | sangar
# Processing Record 28 of Set 4 | walvis bay
# Processing Record 29 of Set 4 | belaya gora
# Processing Record 30 of Set 4 | flin flon
# Processing Record 31 of Set 4 | messina
# Processing Record 32 of Set 4 | new norfolk
# Processing Record 33 of Set 4 | geraldton
# Processing Record 34 of Set 4 | fairbanks
# Processing Record 35 of Set 4 | kolomyya
# Processing Record 36 of Set 4 | yarmouth
# Processing Record 37 of Set 4 | bonavista
# Processing Record 38 of Set 4 | kruisfontein
# Processing Record 39 of Set 4 | bambous virieux
# Processing Record 40 of Set 4 | katsuura
# Processing Record 41 of Set 4 | tasiilaq
# Processing Record 42 of Set 4 | saint-augustin
# Processing Record 43 of Set 4 | lorengau
# Processing Record 44 of Set 4 | xai-xai
# Processing Record 45 of Set 4 | irpa irpa
# Processing Record 46 of Set 4 | mahebourg
# Processing Record 47 of Set 4 | havre-saint-pierre
# Processing Record 48 of Set 4 | kulhudhuffushi
# Processing Record 49 of Set 4 | morant bay
# Processing Record 50 of Set 4 | san matias
# Processing Record 1 of Set 5 | mogadishu
# Processing Record 2 of Set 5 | necochea
# Processing Record 3 of Set 5 | faanui
# Processing Record 4 of Set 5 | sinnamary
# Processing Record 5 of Set 5 | avera
# Processing Record 6 of Set 5 | yar-sale
# Processing Record 7 of Set 5 | saint-philippe
# Processing Record 8 of Set 5 | sheregesh
# Processing Record 9 of Set 5 | waipawa
# Processing Record 10 of Set 5 | guerrero negro
# Processing Record 11 of Set 5 | lock haven
# Processing Record 12 of Set 5 | vanimo
# Processing Record 13 of Set 5 | tsihombe
# City not found. Skipping...
# Processing Record 14 of Set 5 | hasaki
# Processing Record 15 of Set 5 | edson
# Processing Record 16 of Set 5 | dong hoi
# Processing Record 17 of Set 5 | clarence town
# Processing Record 18 of Set 5 | amarante do maranhao
# Processing Record 19 of Set 5 | kununurra
# Processing Record 20 of Set 5 | nouadhibou
# Processing Record 21 of Set 5 | klaksvik
# Processing Record 22 of Set 5 | ontario
# Processing Record 23 of Set 5 | senneterre
# Processing Record 24 of Set 5 | linxia
# Processing Record 25 of Set 5 | bakaly
# Processing Record 26 of Set 5 | hamilton
# Processing Record 27 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 28 of Set 5 | bahia blanca
# Processing Record 29 of Set 5 | brae
# Processing Record 30 of Set 5 | raudeberg
# Processing Record 31 of Set 5 | sao gabriel da cachoeira
# Processing Record 32 of Set 5 | darhan
# Processing Record 33 of Set 5 | alofi
# Processing Record 34 of Set 5 | saskylakh
# Processing Record 35 of Set 5 | gizo
# Processing Record 36 of Set 5 | saldanha
# Processing Record 37 of Set 5 | lebu
# Processing Record 38 of Set 5 | igurubi
# Processing Record 39 of Set 5 | dzilam gonzalez
# Processing Record 40 of Set 5 | batemans bay
# Processing Record 41 of Set 5 | muskogee
# Processing Record 42 of Set 5 | atar
# Processing Record 43 of Set 5 | tres arroyos
# Processing Record 44 of Set 5 | leningradskiy
# Processing Record 45 of Set 5 | ha tinh
# Processing Record 46 of Set 5 | krasnoselkup
# Processing Record 47 of Set 5 | nan
# Processing Record 48 of Set 5 | goderich
# Processing Record 49 of Set 5 | bandarbeyla
# Processing Record 50 of Set 5 | nizhneyansk
# City not found. Skipping...
# Processing Record 1 of Set 6 | inuvik
# Processing Record 2 of Set 6 | bonga
# Processing Record 3 of Set 6 | ahipara
# Processing Record 4 of Set 6 | vila franca do campo
# Processing Record 5 of Set 6 | platanos
# Processing Record 6 of Set 6 | chokurdakh
# Processing Record 7 of Set 6 | narsaq
# Processing Record 8 of Set 6 | ostrovnoy
# Processing Record 9 of Set 6 | sao jose da coroa grande
# Processing Record 10 of Set 6 | namibe
# Processing Record 11 of Set 6 | kungurtug
# Processing Record 12 of Set 6 | belmonte
# Processing Record 13 of Set 6 | manokwari
# Processing Record 14 of Set 6 | fougeres
# Processing Record 15 of Set 6 | yagodnoye
# Processing Record 16 of Set 6 | urumqi
# Processing Record 17 of Set 6 | waitati
# Processing Record 18 of Set 6 | bichura
# Processing Record 19 of Set 6 | samusu
# City not found. Skipping...
# Processing Record 20 of Set 6 | te anau
# Processing Record 21 of Set 6 | oparino
# Processing Record 22 of Set 6 | dudinka
# Processing Record 23 of Set 6 | phan rang
# City not found. Skipping...
# Processing Record 24 of Set 6 | ouadda
# Processing Record 25 of Set 6 | mahadday weyne
# City not found. Skipping...
# Processing Record 26 of Set 6 | teluk nibung
# Processing Record 27 of Set 6 | somerset
# Processing Record 28 of Set 6 | hobyo
# Processing Record 29 of Set 6 | fauske
# Processing Record 30 of Set 6 | adrar
# Processing Record 31 of Set 6 | beringovskiy
# Processing Record 32 of Set 6 | vredendal
# Processing Record 33 of Set 6 | pyay
# Processing Record 34 of Set 6 | teahupoo
# Processing Record 35 of Set 6 | hay river
# Processing Record 36 of Set 6 | general jose eduvigis diaz
# Processing Record 37 of Set 6 | pasni
# Processing Record 38 of Set 6 | mercedes
# Processing Record 39 of Set 6 | colomi
# Processing Record 40 of Set 6 | ancud
# Processing Record 41 of Set 6 | coquimbo
# Processing Record 42 of Set 6 | rawson
# Processing Record 43 of Set 6 | micheweni
# Processing Record 44 of Set 6 | augusto correa
# Processing Record 45 of Set 6 | broome
# Processing Record 46 of Set 6 | mutum
# Processing Record 47 of Set 6 | gambela
# Processing Record 48 of Set 6 | asbestos
# Processing Record 49 of Set 6 | husavik
# Processing Record 50 of Set 6 | kavieng
# Processing Record 1 of Set 7 | kyabe
# Processing Record 2 of Set 7 | cloquet
# Processing Record 3 of Set 7 | lavrentiya
# Processing Record 4 of Set 7 | sorong
# Processing Record 5 of Set 7 | gazojak
# Processing Record 6 of Set 7 | saint george
# Processing Record 7 of Set 7 | souillac
# Processing Record 8 of Set 7 | puerto cabezas
# Processing Record 9 of Set 7 | bolshoy tsaryn
# City not found. Skipping...
# Processing Record 10 of Set 7 | laguna
# Processing Record 11 of Set 7 | kashan
# Processing Record 12 of Set 7 | karaul
# City not found. Skipping...
# Processing Record 13 of Set 7 | san jose
# Processing Record 14 of Set 7 | murray bridge
# Processing Record 15 of Set 7 | kawana waters
# City not found. Skipping...
# Processing Record 16 of Set 7 | tilichiki
# Processing Record 17 of Set 7 | banmo
# City not found. Skipping...
# Processing Record 18 of Set 7 | ebebiyin
# Processing Record 19 of Set 7 | nata
# Processing Record 20 of Set 7 | praia da vitoria
# Processing Record 21 of Set 7 | ratangarh
# Processing Record 22 of Set 7 | narayanganj
# Processing Record 23 of Set 7 | leo
# Processing Record 24 of Set 7 | zheleznodorozhnyy
# Processing Record 25 of Set 7 | mocuba
# Processing Record 26 of Set 7 | portland
# Processing Record 27 of Set 7 | viligili
# City not found. Skipping...
# Processing Record 28 of Set 7 | jiblah
# Processing Record 29 of Set 7 | quatre cocos
# Processing Record 30 of Set 7 | alotau
# City not found. Skipping...
# Processing Record 31 of Set 7 | namatanai
# Processing Record 32 of Set 7 | zaltan
# Processing Record 33 of Set 7 | mount gambier
# Processing Record 34 of Set 7 | tazmalt
# Processing Record 35 of Set 7 | stephenville
# Processing Record 36 of Set 7 | puerto ayacucho
# Processing Record 37 of Set 7 | evensk
# Processing Record 38 of Set 7 | viedma
# Processing Record 39 of Set 7 | roald
# Processing Record 40 of Set 7 | midland
# Processing Record 41 of Set 7 | lora del rio
# Processing Record 42 of Set 7 | sao joao da barra
# Processing Record 43 of Set 7 | nsanje
# Processing Record 44 of Set 7 | cabo san lucas
# Processing Record 45 of Set 7 | nyrob
# Processing Record 46 of Set 7 | ketchikan
# Processing Record 47 of Set 7 | kenai
# Processing Record 48 of Set 7 | middelkerke
# Processing Record 49 of Set 7 | mulege
# Processing Record 50 of Set 7 | bull savanna
# Processing Record 1 of Set 8 | port-cartier
# Processing Record 2 of Set 8 | arrifes
# Processing Record 3 of Set 8 | roma
# Processing Record 4 of Set 8 | la ronge
# Processing Record 5 of Set 8 | manoel urbano
# Processing Record 6 of Set 8 | tabiauea
# City not found. Skipping...
# Processing Record 7 of Set 8 | luderitz
# Processing Record 8 of Set 8 | seabra
# Processing Record 9 of Set 8 | marcona
# City not found. Skipping...
# Processing Record 10 of Set 8 | kawambwa
# Processing Record 11 of Set 8 | chicama
# Processing Record 12 of Set 8 | nago
# Processing Record 13 of Set 8 | labutta
# City not found. Skipping...
# Processing Record 14 of Set 8 | natal
# Processing Record 15 of Set 8 | lake havasu city
# Processing Record 16 of Set 8 | durban
# Processing Record 17 of Set 8 | tanabe
# Processing Record 18 of Set 8 | asau
# Processing Record 19 of Set 8 | paita
# Processing Record 20 of Set 8 | komsomolskiy
# Processing Record 21 of Set 8 | fukue
# Processing Record 22 of Set 8 | flinders
# Processing Record 23 of Set 8 | pangkalanbuun
# Processing Record 24 of Set 8 | maceio
# Processing Record 25 of Set 8 | tiksi
# Processing Record 26 of Set 8 | saint-dizier
# Processing Record 27 of Set 8 | kawai
# Processing Record 28 of Set 8 | qaqortoq
# Processing Record 29 of Set 8 | prince rupert
# Processing Record 30 of Set 8 | isangel
# Processing Record 31 of Set 8 | gander
# Processing Record 32 of Set 8 | bima
# Processing Record 33 of Set 8 | sigli
# Processing Record 34 of Set 8 | haines junction
# Processing Record 35 of Set 8 | campina verde
# Processing Record 36 of Set 8 | auburn
# Processing Record 37 of Set 8 | pilar
# Processing Record 38 of Set 8 | planeta rica
# Processing Record 39 of Set 8 | pizarro
# Processing Record 40 of Set 8 | oytal
# Processing Record 41 of Set 8 | tuy hoa
# Processing Record 42 of Set 8 | kloulklubed
# Processing Record 43 of Set 8 | west plains
# Processing Record 44 of Set 8 | ueckermunde
# Processing Record 45 of Set 8 | havoysund
# Processing Record 46 of Set 8 | verkhnetulomskiy
# Processing Record 47 of Set 8 | limbang
# Processing Record 48 of Set 8 | tessalit
# Processing Record 49 of Set 8 | magnitogorsk
# Processing Record 50 of Set 8 | thongwa
# Processing Record 1 of Set 9 | leshukonskoye
# Processing Record 2 of Set 9 | montenegro
# Processing Record 3 of Set 9 | schwabisch hall
# Processing Record 4 of Set 9 | brisbane
# Processing Record 5 of Set 9 | port hardy
# Processing Record 6 of Set 9 | kalmunai
# Processing Record 7 of Set 9 | port-gentil
# Processing Record 8 of Set 9 | sakata
# Processing Record 9 of Set 9 | byron bay
# Processing Record 10 of Set 9 | manjacaze
# Processing Record 11 of Set 9 | kupang
# Processing Record 12 of Set 9 | olinda
# Processing Record 13 of Set 9 | vao
# Processing Record 14 of Set 9 | kjollefjord
# Processing Record 15 of Set 9 | san jacinto
# Processing Record 16 of Set 9 | voyvozh
# Processing Record 17 of Set 9 | emerald
# Processing Record 18 of Set 9 | biga
# Processing Record 19 of Set 9 | zarechnyy
# Processing Record 20 of Set 9 | jiaohe
# Processing Record 21 of Set 9 | christchurch
# Processing Record 22 of Set 9 | bristol
# Processing Record 23 of Set 9 | ygatimi
# Processing Record 24 of Set 9 | pontes e lacerda
# Processing Record 25 of Set 9 | hofn
# Processing Record 26 of Set 9 | georgetown
# Processing Record 27 of Set 9 | tukrah
# Processing Record 28 of Set 9 | tambura
# Processing Record 29 of Set 9 | elko
# Processing Record 30 of Set 9 | pochutla
# Processing Record 31 of Set 9 | milingimbi
# City not found. Skipping...
# Processing Record 32 of Set 9 | kodinsk
# Processing Record 33 of Set 9 | kurumkan
# Processing Record 34 of Set 9 | provideniya
# Processing Record 35 of Set 9 | camopi
# Processing Record 36 of Set 9 | frederikshavn
# Processing Record 37 of Set 9 | hunchun
# Processing Record 38 of Set 9 | sooke
# Processing Record 39 of Set 9 | komsomolets
# Processing Record 40 of Set 9 | florianopolis
# Processing Record 41 of Set 9 | creston
# Processing Record 42 of Set 9 | cacule
# Processing Record 43 of Set 9 | severo-yeniseyskiy
# Processing Record 44 of Set 9 | eenhana
# Processing Record 45 of Set 9 | nicoya
# Processing Record 46 of Set 9 | maturin
# Processing Record 47 of Set 9 | chumphon
# Processing Record 48 of Set 9 | sur
# Processing Record 49 of Set 9 | fairview
# Processing Record 50 of Set 9 | umzimvubu
# City not found. Skipping...
# Processing Record 1 of Set 10 | nhulunbuy
# Processing Record 2 of Set 10 | kibondo
# Processing Record 3 of Set 10 | aswan
# Processing Record 4 of Set 10 | yerbogachen
# Processing Record 5 of Set 10 | kondagaon
# Processing Record 6 of Set 10 | mbuji-mayi
# Processing Record 7 of Set 10 | basco
# Processing Record 8 of Set 10 | puerto escondido
# Processing Record 9 of Set 10 | gunjur
# Processing Record 10 of Set 10 | terrak
# Processing Record 11 of Set 10 | lompoc
# Processing Record 12 of Set 10 | kamalpur
# Processing Record 13 of Set 10 | ipixuna
# Processing Record 14 of Set 10 | hovd
# Processing Record 15 of Set 10 | mandiana
# Processing Record 16 of Set 10 | keetmanshoop
# Processing Record 17 of Set 10 | san luis
# Processing Record 18 of Set 10 | bosaso
# Processing Record 19 of Set 10 | kidal
# Processing Record 20 of Set 10 | san anselmo
# Processing Record 21 of Set 10 | bagdarin
# Processing Record 22 of Set 10 | nguru
# Processing Record 23 of Set 10 | dingle
# Processing Record 24 of Set 10 | nioro
# Processing Record 25 of Set 10 | tabou
# Processing Record 26 of Set 10 | mastic beach
# Processing Record 27 of Set 10 | churapcha
# Processing Record 28 of Set 10 | severo-kurilsk
# Processing Record 29 of Set 10 | salto
# Processing Record 30 of Set 10 | svetlyy
# Processing Record 31 of Set 10 | coahuayana
# Processing Record 32 of Set 10 | surt
# Processing Record 33 of Set 10 | tawau
# Processing Record 34 of Set 10 | stornoway
# Processing Record 35 of Set 10 | buala
# Processing Record 36 of Set 10 | tiznit
# Processing Record 37 of Set 10 | san isidro
# Processing Record 38 of Set 10 | aksu
# Processing Record 39 of Set 10 | makat
# Processing Record 40 of Set 10 | oktyabrskoye
# Processing Record 41 of Set 10 | frunze
# Processing Record 42 of Set 10 | turayf
# Processing Record 43 of Set 10 | gayeri
# Processing Record 44 of Set 10 | sobolevo
# Processing Record 45 of Set 10 | baracoa
# Processing Record 46 of Set 10 | pong
# Processing Record 47 of Set 10 | nyurba
# Processing Record 48 of Set 10 | zhanakorgan
# Processing Record 49 of Set 10 | freeport
# Processing Record 50 of Set 10 | presidencia roque saenz pena
# Processing Record 1 of Set 11 | acajutla
# Processing Record 2 of Set 11 | monte gordo
# Processing Record 3 of Set 11 | bargal
# City not found. Skipping...
# Processing Record 4 of Set 11 | krasnyy yar
# Processing Record 5 of Set 11 | saint anthony
# Processing Record 6 of Set 11 | alyangula
# Processing Record 7 of Set 11 | mendota
# Processing Record 8 of Set 11 | ninghai
# Processing Record 9 of Set 11 | shibarghan
# City not found. Skipping...
# Processing Record 10 of Set 11 | chor
# Processing Record 11 of Set 11 | zhob
# Processing Record 12 of Set 11 | yenotayevka
# Processing Record 13 of Set 11 | bay city
# Processing Record 14 of Set 11 | castlemaine
# Processing Record 15 of Set 11 | lerwick
# Processing Record 16 of Set 11 | lata
# Processing Record 17 of Set 11 | vila
# Processing Record 18 of Set 11 | omboue
# Processing Record 19 of Set 11 | swan river
# Processing Record 20 of Set 11 | galgani
# City not found. Skipping...
# Processing Record 21 of Set 11 | palu
# Processing Record 22 of Set 11 | cherskiy
# Processing Record 23 of Set 11 | ejby
# Processing Record 24 of Set 11 | kontagora
# Processing Record 25 of Set 11 | kahului
# Processing Record 26 of Set 11 | buloh kasap
# Processing Record 27 of Set 11 | saleaula
# City not found. Skipping...
# Processing Record 28 of Set 11 | biak
# Processing Record 29 of Set 11 | muros
# Processing Record 30 of Set 11 | tyret pervaya
# Processing Record 31 of Set 11 | usinsk
# Processing Record 32 of Set 11 | pamanukan
# Processing Record 33 of Set 11 | le port
# Processing Record 34 of Set 11 | sault sainte marie
# Processing Record 35 of Set 11 | antofagasta
# Processing Record 36 of Set 11 | pyapon
# Processing Record 37 of Set 11 | vila do maio
# Processing Record 38 of Set 11 | dwarka
# Processing Record 39 of Set 11 | islamkot
# Processing Record 40 of Set 11 | nurota
# Processing Record 41 of Set 11 | sunland park
# Processing Record 42 of Set 11 | pitimbu
# Processing Record 43 of Set 11 | diffa
# Processing Record 44 of Set 11 | kosa
# Processing Record 45 of Set 11 | san felipe
# Processing Record 46 of Set 11 | colesberg
# Processing Record 47 of Set 11 | almaznyy
# Processing Record 48 of Set 11 | meadow lake
# Processing Record 49 of Set 11 | kuche
# City not found. Skipping...
# Processing Record 50 of Set 11 | yankton
# Processing Record 1 of Set 12 | borger
# Processing Record 2 of Set 12 | tevaitoa
# Processing Record 3 of Set 12 | khani
# Processing Record 4 of Set 12 | sakakah
# Processing Record 5 of Set 12 | perbaungan
# Processing Record 6 of Set 12 | tanout
# Processing Record 7 of Set 12 | santa fe
# Processing Record 8 of Set 12 | iralaya
# Processing Record 9 of Set 12 | cap-chat
# Processing Record 10 of Set 12 | matamoros
# Processing Record 11 of Set 12 | kinablangan
# Processing Record 12 of Set 12 | alice springs
# Processing Record 13 of Set 12 | mpanda
# Processing Record 14 of Set 12 | glendive
# Processing Record 15 of Set 12 | bazpur
# Processing Record 16 of Set 12 | beshpagir
# Processing Record 17 of Set 12 | empa
# City not found. Skipping...
# Processing Record 18 of Set 12 | stoughton
# Processing Record 19 of Set 12 | beitbridge
# Processing Record 20 of Set 12 | pachora
# Processing Record 21 of Set 12 | dukat
# Processing Record 22 of Set 12 | acapulco
# Processing Record 23 of Set 12 | aksarka
# Processing Record 24 of Set 12 | aklavik
# Processing Record 25 of Set 12 | riyadh
# Processing Record 26 of Set 12 | sawakin
# Processing Record 27 of Set 12 | babanusah
# City not found. Skipping...
# Processing Record 28 of Set 12 | madang
# Processing Record 29 of Set 12 | pak phanang
# Processing Record 30 of Set 12 | nizhniy ingash
# Processing Record 31 of Set 12 | lawton
# Processing Record 32 of Set 12 | yatou
# Processing Record 33 of Set 12 | carinhanha
# Processing Record 34 of Set 12 | la macarena
# Processing Record 35 of Set 12 | beirut
# Processing Record 36 of Set 12 | wilkie
# Processing Record 37 of Set 12 | chapaevsk
# Processing Record 38 of Set 12 | marquette
# Processing Record 39 of Set 12 | slave lake
# Processing Record 40 of Set 12 | abu kamal
# Processing Record 41 of Set 12 | sohagpur
# Processing Record 42 of Set 12 | mayumba
# Processing Record 43 of Set 12 | half moon bay
# Processing Record 44 of Set 12 | metro
# Processing Record 45 of Set 12 | san jeronimo
# Processing Record 46 of Set 12 | kieta
# Processing Record 47 of Set 12 | kapit
# Processing Record 48 of Set 12 | chagda
# City not found. Skipping...
# Processing Record 49 of Set 12 | bartica
# Processing Record 50 of Set 12 | matagami
# Processing Record 1 of Set 13 | pryozerne
# Processing Record 2 of Set 13 | rovaniemi
# Processing Record 3 of Set 13 | sinolon
# Processing Record 4 of Set 13 | ginir
# Processing Record 5 of Set 13 | niquelandia
# Processing Record 6 of Set 13 | margate
# Processing Record 7 of Set 13 | chumikan
# Processing Record 8 of Set 13 | parrita
# Processing Record 9 of Set 13 | bac lieu
# Processing Record 10 of Set 13 | champerico
# Processing Record 11 of Set 13 | west bay
# Processing Record 12 of Set 13 | los llanos de aridane
# Processing Record 13 of Set 13 | gat
# Processing Record 14 of Set 13 | ginda
# Processing Record 15 of Set 13 | xuanhua
# Processing Record 16 of Set 13 | timoteo
# Processing Record 17 of Set 13 | gull lake
# Processing Record 18 of Set 13 | along
# Processing Record 19 of Set 13 | teberda
# Processing Record 20 of Set 13 | westport
# Processing Record 21 of Set 13 | badhni kalan
# Processing Record 22 of Set 13 | paysandu
# Processing Record 23 of Set 13 | xichang
# Processing Record 24 of Set 13 | strezhevoy
# Processing Record 25 of Set 13 | pauini
# Processing Record 26 of Set 13 | sistranda
# Processing Record 27 of Set 13 | tobermory
# Processing Record 28 of Set 13 | akita
# Processing Record 29 of Set 13 | ugoofaaru
# Processing Record 30 of Set 13 | jacareacanga
# Processing Record 31 of Set 13 | tsabong
# Processing Record 32 of Set 13 | santa marta
# Processing Record 33 of Set 13 | quiniput
# Processing Record 34 of Set 13 | vila velha
# Processing Record 35 of Set 13 | college
# Processing Record 36 of Set 13 | louisbourg
# City not found. Skipping...
# Processing Record 37 of Set 13 | baruun-urt
# Processing Record 38 of Set 13 | krabi
# Processing Record 39 of Set 13 | mandera
# Processing Record 40 of Set 13 | kudahuvadhoo
# Processing Record 41 of Set 13 | dongargaon
# Processing Record 42 of Set 13 | eregli
# Processing Record 43 of Set 13 | rzeszow
# Processing Record 44 of Set 13 | panaba
# Processing Record 45 of Set 13 | salalah
# Processing Record 46 of Set 13 | quthing
# Processing Record 47 of Set 13 | baykit
# Processing Record 48 of Set 13 | haysville
# Processing Record 49 of Set 13 | muravlenko
# Processing Record 50 of Set 13 | agva
# City not found. Skipping...
# Processing Record 1 of Set 14 | shahrud
# Processing Record 2 of Set 14 | honiara
# Processing Record 3 of Set 14 | bajil
# Processing Record 4 of Set 14 | bairiki
# Processing Record 5 of Set 14 | aykhal
# Processing Record 6 of Set 14 | cayenne
# Processing Record 7 of Set 14 | trabzon
# Processing Record 8 of Set 14 | altea
# Processing Record 9 of Set 14 | sirjan
# Processing Record 10 of Set 14 | tapaua
# City not found. Skipping...
# Processing Record 11 of Set 14 | san andres
# Processing Record 12 of Set 14 | kamyshla
# Processing Record 13 of Set 14 | valparaiso
# Processing Record 14 of Set 14 | aktas
# Processing Record 15 of Set 14 | lima
# Processing Record 16 of Set 14 | soldotna
# Processing Record 17 of Set 14 | yining
# Processing Record 18 of Set 14 | maldonado
# Processing Record 19 of Set 14 | nayoro
# Processing Record 20 of Set 14 | batagay
# Processing Record 21 of Set 14 | shahr-e babak
# Processing Record 22 of Set 14 | yulara
# Processing Record 23 of Set 14 | prainha
# Processing Record 24 of Set 14 | san patricio
# Processing Record 25 of Set 14 | arlit
# Processing Record 26 of Set 14 | roebourne
# Processing Record 27 of Set 14 | lisa
# Processing Record 28 of Set 14 | erdenet
# Processing Record 29 of Set 14 | banepa
# Processing Record 30 of Set 14 | chililabombwe
# Processing Record 31 of Set 14 | talcahuano
# Processing Record 32 of Set 14 | ganzhou
# Processing Record 33 of Set 14 | acari
# Processing Record 34 of Set 14 | kaura namoda
# Processing Record 35 of Set 14 | filadelfia
# Processing Record 36 of Set 14 | novocheboksarsk
# Processing Record 37 of Set 14 | ryotsu
# Processing Record 38 of Set 14 | maguri-racatau
# City not found. Skipping...
# Processing Record 39 of Set 14 | brokopondo
# Processing Record 40 of Set 14 | mecca
# Processing Record 41 of Set 14 | osmaniye
# Processing Record 42 of Set 14 | gimli
# Processing Record 43 of Set 14 | turbat
# Processing Record 44 of Set 14 | canavieiras
# Processing Record 45 of Set 14 | pringsewu
# Processing Record 46 of Set 14 | hirara
# Processing Record 47 of Set 14 | gamba
# Processing Record 48 of Set 14 | djibo
# Processing Record 49 of Set 14 | bubaque
# Processing Record 50 of Set 14 | derzhavinsk
# Processing Record 1 of Set 15 | weatherford
# Processing Record 2 of Set 15 | madras
# Processing Record 3 of Set 15 | amravati
# Processing Record 4 of Set 15 | buariki
# City not found. Skipping...
# Processing Record 5 of Set 15 | arman
# Processing Record 6 of Set 15 | kamenskoye
# City not found. Skipping...
# Processing Record 7 of Set 15 | touros
# Processing Record 8 of Set 15 | samarai
# Processing Record 9 of Set 15 | pacific grove
# Processing Record 10 of Set 15 | panlaitan
# Processing Record 11 of Set 15 | celestun
# Processing Record 12 of Set 15 | svetlogorsk
# Processing Record 13 of Set 15 | pucallpa
# Processing Record 14 of Set 15 | mount pleasant
# Processing Record 15 of Set 15 | bowen
# Processing Record 16 of Set 15 | hue
# Processing Record 17 of Set 15 | kirakira
# Processing Record 18 of Set 15 | hami
# Processing Record 19 of Set 15 | halalo
# City not found. Skipping...
# Processing Record 20 of Set 15 | pisco
# Processing Record 21 of Set 15 | sesheke
# Processing Record 22 of Set 15 | grand gaube
# Processing Record 23 of Set 15 | nemuro
# Processing Record 24 of Set 15 | carutapera
# Processing Record 25 of Set 15 | preston
# Processing Record 26 of Set 15 | balta
# Processing Record 27 of Set 15 | neuquen
# Processing Record 28 of Set 15 | bayan
# Processing Record 29 of Set 15 | tutoia
# Processing Record 30 of Set 15 | hobbs
# Processing Record 31 of Set 15 | teacapan
# Processing Record 32 of Set 15 | cochrane
# Processing Record 33 of Set 15 | stoyba
# City not found. Skipping...
# Processing Record 34 of Set 15 | oriximina
# Processing Record 35 of Set 15 | hvammstangi
# City not found. Skipping...
# Processing Record 36 of Set 15 | ust-maya
# Processing Record 37 of Set 15 | tullow
# Processing Record 38 of Set 15 | raipur
# Processing Record 39 of Set 15 | bathsheba
# Processing Record 40 of Set 15 | saint-prosper
# Processing Record 41 of Set 15 | ybbs
# City not found. Skipping...
# Processing Record 42 of Set 15 | nhamunda
# Processing Record 43 of Set 15 | kita
# Processing Record 44 of Set 15 | cardston
# Processing Record 45 of Set 15 | ardakan
# Processing Record 46 of Set 15 | iglesias
# Processing Record 47 of Set 15 | werda
# Processing Record 48 of Set 15 | teodoro sampaio
# Processing Record 49 of Set 15 | bani walid
# Processing Record 50 of Set 15 | khormuj
# City not found. Skipping...
# Processing Record 1 of Set 16 | rocha
# Processing Record 2 of Set 16 | moron
# Processing Record 3 of Set 16 | novokruchininskiy
# Processing Record 4 of Set 16 | alihe
# Processing Record 5 of Set 16 | bangassou
# Processing Record 6 of Set 16 | upernavik
# Processing Record 7 of Set 16 | ushuaia
# Processing Record 8 of Set 16 | nanortalik
# Processing Record 9 of Set 16 | iracoubo
# Processing Record 10 of Set 16 | longyearbyen
# Processing Record 11 of Set 16 | attawapiskat
# City not found. Skipping...
# Processing Record 12 of Set 16 | arzgir
# Processing Record 13 of Set 16 | luba
# Processing Record 14 of Set 16 | tecoanapa
# Processing Record 15 of Set 16 | deputatskiy
# Processing Record 16 of Set 16 | vaini
# Processing Record 17 of Set 16 | tashtagol
# Processing Record 18 of Set 16 | kodiak
# Processing Record 19 of Set 16 | hermanus
# Processing Record 20 of Set 16 | cervenia
# Processing Record 21 of Set 16 | ipueiras
# Processing Record 22 of Set 16 | hilo
# Processing Record 23 of Set 16 | butaritari
# Processing Record 24 of Set 16 | paamiut
# Processing Record 25 of Set 16 | terrace
# Processing Record 26 of Set 16 | vaitupu
# City not found. Skipping...
# Processing Record 27 of Set 16 | olafsvik
# Processing Record 28 of Set 16 | busselton
# Processing Record 29 of Set 16 | barentsburg
# City not found. Skipping...
# Processing Record 30 of Set 16 | dharan
# Processing Record 31 of Set 16 | sentyabrskiy
# City not found. Skipping...
# Processing Record 32 of Set 16 | steinbach
# Processing Record 33 of Set 16 | charcas
# Processing Record 34 of Set 16 | cockburn town
# Processing Record 35 of Set 16 | guangyuan
# Processing Record 36 of Set 16 | puerto ayora
# Processing Record 37 of Set 16 | eureka
# Processing Record 38 of Set 16 | poum
# Processing Record 39 of Set 16 | port alfred
# Processing Record 40 of Set 16 | palmer
# Processing Record 41 of Set 16 | astana
# Processing Record 42 of Set 16 | nakhon thai
# Processing Record 43 of Set 16 | kaitangata
# Processing Record 44 of Set 16 | hithadhoo
# Processing Record 45 of Set 16 | kavaratti
# Processing Record 46 of Set 16 | tezu
# Processing Record 47 of Set 16 | makakilo city
# Processing Record 48 of Set 16 | phalodi
# Processing Record 49 of Set 16 | punta arenas
# Processing Record 50 of Set 16 | avarua
# Processing Record 51 of Set 16 | atuona
# Processing Record 52 of Set 16 | banda aceh
# Processing Record 53 of Set 16 | colotlan
# Processing Record 54 of Set 16 | ulladulla
# Processing Record 55 of Set 16 | belushya guba
# City not found. Skipping...
# Processing Record 1 of Set 17 | talnakh
# Processing Record 2 of Set 17 | tuktoyaktuk
# Processing Record 3 of Set 17 | salinas
# Processing Record 4 of Set 17 | rikitea
# Processing Record 5 of Set 17 | caravelas
# Processing Record 6 of Set 17 | thompson
# Processing Record 7 of Set 17 | okhotsk
# Processing Record 8 of Set 17 | boyolangu
# Processing Record 9 of Set 17 | nishihara
# Processing Record 10 of Set 17 | nome
# Processing Record 11 of Set 17 | san cristobal
# Processing Record 12 of Set 17 | port lincoln
# Processing Record 13 of Set 17 | mehamn
# Processing Record 14 of Set 17 | mount isa
# Processing Record 15 of Set 17 | tarudant
# City not found. Skipping...
# Processing Record 16 of Set 17 | meulaboh
# Processing Record 17 of Set 17 | albany
# Processing Record 18 of Set 17 | guanica
# Processing Record 19 of Set 17 | meyungs
# City not found. Skipping...
# Processing Record 20 of Set 17 | arraial do cabo
# Processing Record 21 of Set 17 | sitka
# Processing Record 22 of Set 17 | muli
# Processing Record 23 of Set 17 | chuy
# Processing Record 24 of Set 17 | bluff
# Processing Record 25 of Set 17 | sao filipe
# Processing Record 26 of Set 17 | marsa matruh
# Processing Record 27 of Set 17 | tahta
# Processing Record 28 of Set 17 | hobart
# Processing Record 29 of Set 17 | barrow
# Processing Record 30 of Set 17 | hauterive
# Processing Record 31 of Set 17 | grand river south east
# City not found. Skipping...
# Processing Record 32 of Set 17 | high level
# Processing Record 33 of Set 17 | victoria
# Processing Record 34 of Set 17 | faya
# Processing Record 35 of Set 17 | yantal
# Processing Record 36 of Set 17 | qaanaaq
# Processing Record 37 of Set 17 | bengkulu
# Processing Record 38 of Set 17 | ilulissat
# Processing Record 39 of Set 17 | castro
# Processing Record 40 of Set 17 | qasigiannguit
# Processing Record 41 of Set 17 | jamestown
# Processing Record 42 of Set 17 | agadez
# Processing Record 43 of Set 17 | iqaluit
# Processing Record 44 of Set 17 | anadyr
# Processing Record 45 of Set 17 | safaga
# Processing Record 46 of Set 17 | bredasdorp
# Processing Record 47 of Set 17 | pevek
# Processing Record 48 of Set 17 | taolanaro
# City not found. Skipping...
# Processing Record 49 of Set 17 | henties bay
# Processing Record 50 of Set 17 | nyimba
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/lh/b41zj8m157b89wb32ykjqsbm0000gn/T/ipykernel_69334/218430341.py in <module>
#      28             set_count += 1
#      29             record_count = 1
# ---> 30             time.sleep(60)
#      31
#      32         # Create endpoint URL with each city.
#
# KeyboardInterrupt:

# %%
len(city_data)
# Out:
# 792

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City      Lat       Lng       Description  Max Temp  Humidity  \
# 0     Upernavik  72.7868  -56.1549        light rain     39.94        97
# 1       Ushuaia -54.8000  -68.3000     broken clouds     38.86        60
# 2    Nanortalik  60.1432  -45.2371  scattered clouds     39.06        91
# 3      Iracoubo   5.4802  -53.2011     moderate rain     76.03        88
# 4  Longyearbyen  78.2186   15.6401     broken clouds     44.44        81
# 5        Arzgir  45.3728   44.2206  scattered clouds     83.57        43
# 6          Luba   3.4568    8.5547        light rain     75.09        90
# 7     Tecoanapa  16.5167  -98.7500   overcast clouds     79.52        84
# 8   Deputatskiy  69.3000  139.9000   overcast clouds     48.61        78
# 9         Vaini -21.2000 -175.2000        few clouds     75.36        78
#
#    Cloudiness  Wind Speed Country                 Date
# 0         100       10.40      GL  2022-08-18 04:28:13
# 1          75       12.66      AR  2022-08-18 04:28:13
# 2          36        8.63      GL  2022-08-18 04:28:14
# 3          29        5.44      GF  2022-08-18 04:28:14
# 4          75        3.44      SJ  2022-08-18 04:28:14
# 5          37        8.12      RU  2022-08-18 04:28:15
# 6         100        4.99      GQ  2022-08-18 04:28:15
# 7         100        2.73      MX  2022-08-18 04:28:16
# 8         100        5.21      RU  2022-08-18 04:28:16
# 9          20       13.80      TO  2022-08-18 04:28:16

# %%
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Description"]

# %%
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0     Upernavik      GL  72.7868  -56.1549     39.94        97         100
# 1       Ushuaia      AR -54.8000  -68.3000     38.86        60          75
# 2    Nanortalik      GL  60.1432  -45.2371     39.06        91          36
# 3      Iracoubo      GF   5.4802  -53.2011     76.03        88          29
# 4  Longyearbyen      SJ  78.2186   15.6401     44.44        81          75
# 5        Arzgir      RU  45.3728   44.2206     83.57        43          37
# 6          Luba      GQ   3.4568    8.5547     75.09        90         100
# 7     Tecoanapa      MX  16.5167  -98.7500     79.52        84         100
# 8   Deputatskiy      RU  69.3000  139.9000     48.61        78         100
# 9         Vaini      TO -21.2000 -175.2000     75.36        78          20
#
#    Wind Speed       Description
# 0       10.40        light rain
# 1       12.66     broken clouds
# 2        8.63  scattered clouds
# 3        5.44     moderate rain
# 4        3.44     broken clouds
# 5        8.12  scattered clouds
# 6        4.99        light rain
# 7        2.73   overcast clouds
# 8        5.21   overcast clouds
# 9       13.80        few clouds

# %%
city_data_df.rename(columns={"Description": "Current Description"}, inplace=True)

# %%
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0     Upernavik      GL  72.7868  -56.1549     39.94        97         100
# 1       Ushuaia      AR -54.8000  -68.3000     38.86        60          75
# 2    Nanortalik      GL  60.1432  -45.2371     39.06        91          36
# 3      Iracoubo      GF   5.4802  -53.2011     76.03        88          29
# 4  Longyearbyen      SJ  78.2186   15.6401     44.44        81          75
# 5        Arzgir      RU  45.3728   44.2206     83.57        43          37
# 6          Luba      GQ   3.4568    8.5547     75.09        90         100
# 7     Tecoanapa      MX  16.5167  -98.7500     79.52        84         100
# 8   Deputatskiy      RU  69.3000  139.9000     48.61        78         100
# 9         Vaini      TO -21.2000 -175.2000     75.36        78          20
#
#    Wind Speed Current Description
# 0       10.40          light rain
# 1       12.66       broken clouds
# 2        8.63    scattered clouds
# 3        5.44       moderate rain
# 4        3.44       broken clouds
# 5        8.12    scattered clouds
# 6        4.99          light rain
# 7        2.73     overcast clouds
# 8        5.21     overcast clouds
# 9       13.80          few clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
