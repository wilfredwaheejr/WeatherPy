# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 741

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c3236ae67f370d8b4590822fc7475efb

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in our list.
for i in range(len(cities)):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + cities[i]
    
# Loop through all the cities in the list.
    for i, city in enumerate(cities):

        # Group cities in sets of 50 for logging purposes.
        if (i % 50 == 0 and i >= 50):
            set_count += 1
            record_count = 1
            time.sleep(60)

        # Create endpoint URL with each city.
        city_url = url + "&q=" + city.replace(" ","+")

        # Log the URL, record, and set numbers and the city.
        print(f"Processing Record {record_count} of Set {set_count} | {city}")
        # Add 1 to the record count.
        record_count += 1
    
# Run an API request for each of the cities.
        try:
            # Parse the JSON and retrieve data.
            city_weather = requests.get(city_url).json()
            # Parse out the needed data.
            city_lat = city_weather["coord"]["lat"]
            city_lng = city_weather["coord"]["lon"]
            city_max_temp = city_weather["main"]["temp_max"]
            city_humidity = city_weather["main"]["humidity"]
            city_clouds = city_weather["clouds"]["all"]
            city_wind = city_weather["wind"]["speed"]
            city_country = city_weather["sys"]["country"]
            # Convert the date to ISO standard.
            city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
            # Append the city information into city_data list.
            city_data.append({"City": city.title(),
                              "Lat": city_lat,
                              "Lng": city_lng,
                              "Max Temp": city_max_temp,
                              "Humidity": city_humidity,
                              "Cloudiness": city_clouds,
                              "Wind Speed": city_wind,
                              "Country": city_country,
                              "Date": city_date})

# If an error is experienced, skip the city.
        except:
            print("City not found. Skipping...")
            pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | kawalu
# Processing Record 2 of Set 1 | rikitea
# Processing Record 3 of Set 1 | hasaki
# Processing Record 4 of Set 1 | albany
# Processing Record 5 of Set 1 | bela
# Processing Record 6 of Set 1 | avarua
# Processing Record 7 of Set 1 | san francisco
# Processing Record 8 of Set 1 | acari
# Processing Record 9 of Set 1 | ushuaia
# Processing Record 10 of Set 1 | saskylakh
# Processing Record 11 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 12 of Set 1 | boa vista
# Processing Record 13 of Set 1 | zyryanka
# Processing Record 14 of Set 1 | miandrivazo
# Processing Record 15 of Set 1 | qaanaaq
# Processing Record 16 of Set 1 | canby
# Processing Record 17 of Set 1 | upernavik
# Processing Record 18 of Set 1 | cape town
# Processing Record 19 of Set 1 | tuktoyaktuk
# Processing Record 20 of Set 1 | noyabrsk
# Processing Record 21 of Set 1 | la gaulette
# City not found. Skipping...
# Processing Record 22 of Set 1 | port alfred
# Processing Record 23 of Set 1 | itaituba
# Processing Record 24 of Set 1 | sao filipe
# Processing Record 25 of Set 1 | sirajganj
# Processing Record 26 of Set 1 | olafsvik
# Processing Record 27 of Set 1 | puerto baquerizo moreno
# Processing Record 28 of Set 1 | kerchevskiy
# Processing Record 29 of Set 1 | yining
# Processing Record 30 of Set 1 | punta arenas
# Processing Record 31 of Set 1 | busselton
# Processing Record 32 of Set 1 | imisli
# City not found. Skipping...
# Processing Record 33 of Set 1 | mataura
# Processing Record 34 of Set 1 | hermanus
# Processing Record 35 of Set 1 | bluff
# Processing Record 36 of Set 1 | mehamn
# Processing Record 37 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 38 of Set 1 | butaritari
# Processing Record 39 of Set 1 | auki
# Processing Record 40 of Set 1 | hithadhoo
# Processing Record 41 of Set 1 | kaili
# Processing Record 42 of Set 1 | nikolskoye
# Processing Record 43 of Set 1 | labuhan
# Processing Record 44 of Set 1 | jamestown
# Processing Record 45 of Set 1 | rafraf
# Processing Record 46 of Set 1 | heinola
# Processing Record 47 of Set 1 | rosario
# Processing Record 48 of Set 1 | hilo
# Processing Record 49 of Set 1 | geresk
# City not found. Skipping...
# Processing Record 50 of Set 1 | tanabe
# Processing Record 1 of Set 2 | karmaskaly
# Processing Record 2 of Set 2 | tura
# Processing Record 3 of Set 2 | chara
# Processing Record 4 of Set 2 | southbridge
# Processing Record 5 of Set 2 | puerto ayora
# Processing Record 6 of Set 2 | yellowknife
# Processing Record 7 of Set 2 | taoudenni
# Processing Record 8 of Set 2 | bargal
# City not found. Skipping...
# Processing Record 9 of Set 2 | zaraysk
# Processing Record 10 of Set 2 | loa janan
# Processing Record 11 of Set 2 | saint-philippe
# Processing Record 12 of Set 2 | rio negrinho
# Processing Record 13 of Set 2 | fort nelson
# Processing Record 14 of Set 2 | markova
# Processing Record 15 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 16 of Set 2 | markala
# Processing Record 17 of Set 2 | guerrero negro
# Processing Record 18 of Set 2 | kapaa
# Processing Record 19 of Set 2 | mersing
# Processing Record 20 of Set 2 | ambulu
# Processing Record 21 of Set 2 | lebu
# Processing Record 22 of Set 2 | hami
# Processing Record 23 of Set 2 | kaitangata
# Processing Record 24 of Set 2 | ilulissat
# Processing Record 25 of Set 2 | sangar
# Processing Record 26 of Set 2 | clyde river
# Processing Record 27 of Set 2 | slave lake
# Processing Record 28 of Set 2 | bandarbeyla
# Processing Record 29 of Set 2 | faanui
# Processing Record 30 of Set 2 | sioux lookout
# Processing Record 31 of Set 2 | lundazi
# Processing Record 32 of Set 2 | kodiak
# Processing Record 33 of Set 2 | katsuura
# Processing Record 34 of Set 2 | arraial do cabo
# Processing Record 35 of Set 2 | thompson
# Processing Record 36 of Set 2 | smithers
# Processing Record 37 of Set 2 | ankang
# Processing Record 38 of Set 2 | portland
# Processing Record 39 of Set 2 | georgetown
# Processing Record 40 of Set 2 | santiago del estero
# Processing Record 41 of Set 2 | tabou
# Processing Record 42 of Set 2 | atuona
# Processing Record 43 of Set 2 | barbar
# City not found. Skipping...
# Processing Record 44 of Set 2 | dawlatabad
# Processing Record 45 of Set 2 | new norfolk
# Processing Record 46 of Set 2 | aklavik
# Processing Record 47 of Set 2 | ulkan
# Processing Record 48 of Set 2 | kumluca
# Processing Record 49 of Set 2 | ponta do sol
# Processing Record 50 of Set 2 | vaini
# Processing Record 1 of Set 3 | masterton
# Processing Record 2 of Set 3 | tsabong
# Processing Record 3 of Set 3 | longyearbyen
# Processing Record 4 of Set 3 | pevek
# Processing Record 5 of Set 3 | saint-pierre
# Processing Record 6 of Set 3 | hobart
# Processing Record 7 of Set 3 | normandin
# Processing Record 8 of Set 3 | kearney
# Processing Record 9 of Set 3 | buala
# Processing Record 10 of Set 3 | lompoc
# Processing Record 11 of Set 3 | muros
# Processing Record 12 of Set 3 | luderitz
# Processing Record 13 of Set 3 | norman wells
# Processing Record 14 of Set 3 | sexsmith
# Processing Record 15 of Set 3 | camopi
# Processing Record 16 of Set 3 | vestmannaeyjar
# Processing Record 17 of Set 3 | codrington
# Processing Record 18 of Set 3 | tiksi
# Processing Record 19 of Set 3 | east london
# Processing Record 20 of Set 3 | cabo san lucas
# Processing Record 21 of Set 3 | acapulco
# Processing Record 22 of Set 3 | acuna
# City not found. Skipping...
# Processing Record 23 of Set 3 | okandja
# City not found. Skipping...
# Processing Record 24 of Set 3 | sembakung
# Processing Record 25 of Set 3 | huarmey
# Processing Record 26 of Set 3 | tasiilaq
# Processing Record 27 of Set 3 | barrow
# Processing Record 28 of Set 3 | lagoa
# Processing Record 29 of Set 3 | tuatapere
# Processing Record 30 of Set 3 | norrtalje
# Processing Record 31 of Set 3 | mar del plata
# Processing Record 32 of Set 3 | husavik
# Processing Record 33 of Set 3 | pemangkat
# Processing Record 34 of Set 3 | watertown
# Processing Record 35 of Set 3 | carnarvon
# Processing Record 36 of Set 3 | ybbs
# City not found. Skipping...
# Processing Record 37 of Set 3 | puerto quijarro
# Processing Record 38 of Set 3 | san patricio
# Processing Record 39 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 40 of Set 3 | northam
# Processing Record 41 of Set 3 | bredasdorp
# Processing Record 42 of Set 3 | linxia
# Processing Record 43 of Set 3 | doha
# Processing Record 44 of Set 3 | sitka
# Processing Record 45 of Set 3 | port macquarie
# Processing Record 46 of Set 3 | huitzuco
# City not found. Skipping...
# Processing Record 47 of Set 3 | klaksvik
# Processing Record 48 of Set 3 | esperance
# Processing Record 49 of Set 3 | quang ngai
# Processing Record 50 of Set 3 | fortuna
# Processing Record 1 of Set 4 | port elizabeth
# Processing Record 2 of Set 4 | hobyo
# Processing Record 3 of Set 4 | mahebourg
# Processing Record 4 of Set 4 | haines junction
# Processing Record 5 of Set 4 | hofn
# Processing Record 6 of Set 4 | kerva
# Processing Record 7 of Set 4 | zolotinka
# City not found. Skipping...
# Processing Record 8 of Set 4 | mount gambier
# Processing Record 9 of Set 4 | marawi
# Processing Record 10 of Set 4 | port-cartier
# Processing Record 11 of Set 4 | kati
# Processing Record 12 of Set 4 | maghama
# City not found. Skipping...
# Processing Record 13 of Set 4 | salina
# Processing Record 14 of Set 4 | nelson bay
# Processing Record 15 of Set 4 | mount isa
# Processing Record 16 of Set 4 | shache
# Processing Record 17 of Set 4 | byron bay
# Processing Record 18 of Set 4 | vardo
# Processing Record 19 of Set 4 | bria
# Processing Record 20 of Set 4 | dikson
# Processing Record 21 of Set 4 | juneau
# Processing Record 22 of Set 4 | port hardy
# Processing Record 23 of Set 4 | rupert
# Processing Record 24 of Set 4 | oranjemund
# Processing Record 25 of Set 4 | henties bay
# Processing Record 26 of Set 4 | sao joao da barra
# Processing Record 27 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 28 of Set 4 | morant bay
# Processing Record 29 of Set 4 | velykyy burluk
# Processing Record 30 of Set 4 | bonthe
# Processing Record 31 of Set 4 | cayenne
# Processing Record 32 of Set 4 | valdivia
# Processing Record 33 of Set 4 | waingapu
# Processing Record 34 of Set 4 | qujing
# Processing Record 35 of Set 4 | batemans bay
# Processing Record 36 of Set 4 | udachnyy
# Processing Record 37 of Set 4 | paamiut
# Processing Record 38 of Set 4 | caetes
# Processing Record 39 of Set 4 | cagayan de tawi-tawi
# City not found. Skipping...
# Processing Record 40 of Set 4 | sesimbra
# Processing Record 41 of Set 4 | warqla
# City not found. Skipping...
# Processing Record 42 of Set 4 | naftah
# City not found. Skipping...
# Processing Record 43 of Set 4 | sao francisco de assis
# Processing Record 44 of Set 4 | saskatoon
# Processing Record 45 of Set 4 | itoman
# Processing Record 46 of Set 4 | kruisfontein
# Processing Record 47 of Set 4 | kamenskoye
# City not found. Skipping...
# Processing Record 48 of Set 4 | teya
# Processing Record 49 of Set 4 | bowmore
# Processing Record 50 of Set 4 | saint george
# Processing Record 1 of Set 5 | zasechnoye
# Processing Record 2 of Set 5 | lengshuijiang
# Processing Record 3 of Set 5 | nouadhibou
# Processing Record 4 of Set 5 | tanshui
# City not found. Skipping...
# Processing Record 5 of Set 5 | billings
# Processing Record 6 of Set 5 | suoyarvi
# Processing Record 7 of Set 5 | kilindoni
# Processing Record 8 of Set 5 | hervey bay
# Processing Record 9 of Set 5 | san andres
# Processing Record 10 of Set 5 | flin flon
# Processing Record 11 of Set 5 | tumannyy
# City not found. Skipping...
# Processing Record 12 of Set 5 | bambous virieux
# Processing Record 13 of Set 5 | coari
# Processing Record 14 of Set 5 | narsaq
# Processing Record 15 of Set 5 | neyshabur
# Processing Record 16 of Set 5 | sinnai
# Processing Record 17 of Set 5 | meyungs
# City not found. Skipping...
# Processing Record 18 of Set 5 | sambava
# Processing Record 19 of Set 5 | tigil
# Processing Record 20 of Set 5 | beringovskiy
# Processing Record 21 of Set 5 | castro
# Processing Record 22 of Set 5 | port hedland
# Processing Record 23 of Set 5 | kavieng
# Processing Record 24 of Set 5 | aflu
# City not found. Skipping...
# Processing Record 25 of Set 5 | baturaja
# Processing Record 26 of Set 5 | enzan
# Processing Record 27 of Set 5 | dera ismail khan
# Processing Record 28 of Set 5 | umzimvubu
# City not found. Skipping...
# Processing Record 29 of Set 5 | carauari
# Processing Record 30 of Set 5 | payakumbuh
# Processing Record 31 of Set 5 | abalak
# Processing Record 32 of Set 5 | poronaysk
# Processing Record 33 of Set 5 | kingman
# Processing Record 34 of Set 5 | weston
# Processing Record 35 of Set 5 | vila franca do campo
# Processing Record 36 of Set 5 | bali chak
# Processing Record 37 of Set 5 | jinji
# Processing Record 38 of Set 5 | young
# Processing Record 39 of Set 5 | anajatuba
# Processing Record 40 of Set 5 | praya
# Processing Record 41 of Set 5 | dunedin
# Processing Record 42 of Set 5 | samusu
# City not found. Skipping...
# Processing Record 43 of Set 5 | cidreira
# Processing Record 44 of Set 5 | thinadhoo
# Processing Record 45 of Set 5 | tevriz
# Processing Record 46 of Set 5 | stornoway
# Processing Record 47 of Set 5 | bilibino
# Processing Record 48 of Set 5 | panaba
# Processing Record 49 of Set 5 | havoysund
# Processing Record 50 of Set 5 | kudal
# Processing Record 1 of Set 6 | karratha
# Processing Record 2 of Set 6 | camana
# Processing Record 3 of Set 6 | krasnyy oktyabr
# Processing Record 4 of Set 6 | kisanga
# Processing Record 5 of Set 6 | vila velha
# Processing Record 6 of Set 6 | namibe
# Processing Record 7 of Set 6 | ulladulla
# Processing Record 8 of Set 6 | gazanjyk
# Processing Record 9 of Set 6 | grand-santi
# Processing Record 10 of Set 6 | zhigansk
# Processing Record 11 of Set 6 | kokoda
# Processing Record 12 of Set 6 | marquette
# Processing Record 13 of Set 6 | flinders
# Processing Record 14 of Set 6 | semey
# Processing Record 15 of Set 6 | bozoum
# Processing Record 16 of Set 6 | chartres
# Processing Record 17 of Set 6 | altay
# Processing Record 18 of Set 6 | ilinskiy
# Processing Record 19 of Set 6 | strathmore
# Processing Record 20 of Set 6 | cardston
# Processing Record 21 of Set 6 | kodino
# Processing Record 22 of Set 6 | constitucion
# Processing Record 23 of Set 6 | honningsvag
# Processing Record 24 of Set 6 | waipawa
# Processing Record 25 of Set 6 | ust-ilimsk
# Processing Record 26 of Set 6 | la fria
# Processing Record 27 of Set 6 | maravilha
# Processing Record 28 of Set 6 | verkh-usugli
# Processing Record 29 of Set 6 | yarmouth
# Processing Record 30 of Set 6 | salalah
# Processing Record 31 of Set 6 | ribeira grande
# Processing Record 32 of Set 6 | bell ville
# Processing Record 33 of Set 6 | tazovskiy
# Processing Record 34 of Set 6 | sentyabrskiy
# City not found. Skipping...
# Processing Record 35 of Set 6 | alice springs
# Processing Record 36 of Set 6 | mangai
# Processing Record 37 of Set 6 | cherskiy
# Processing Record 38 of Set 6 | bilma
# Processing Record 39 of Set 6 | fukue
# Processing Record 40 of Set 6 | kirkuk
# Processing Record 41 of Set 6 | kemin
# Processing Record 42 of Set 6 | kamenka
# Processing Record 43 of Set 6 | sinkat
# City not found. Skipping...
# Processing Record 44 of Set 6 | crib point
# Processing Record 45 of Set 6 | gimli
# Processing Record 46 of Set 6 | nanyuki
# Processing Record 47 of Set 6 | samarai
# Processing Record 48 of Set 6 | araouane
# Processing Record 49 of Set 6 | saint peter
# Processing Record 50 of Set 6 | victoria
# Processing Record 1 of Set 7 | maniitsoq
# Processing Record 2 of Set 7 | avera
# Processing Record 3 of Set 7 | kovdor
# Processing Record 4 of Set 7 | talnakh
# Processing Record 5 of Set 7 | north platte
# Processing Record 6 of Set 7 | biaora
# Processing Record 7 of Set 7 | grand river south east
# City not found. Skipping...
# Processing Record 8 of Set 7 | sfantu gheorghe
# Processing Record 9 of Set 7 | tukrah
# Processing Record 10 of Set 7 | shirokiy
# Processing Record 11 of Set 7 | hammerfest
# Processing Record 12 of Set 7 | adrar
# Processing Record 13 of Set 7 | okhotsk
# Processing Record 14 of Set 7 | hunchun
# Processing Record 15 of Set 7 | gushikawa
# Processing Record 16 of Set 7 | nara
# Processing Record 17 of Set 7 | marzuq
# Processing Record 18 of Set 7 | poyarkovo
# Processing Record 19 of Set 7 | sorland
# Processing Record 20 of Set 7 | the valley
# Processing Record 21 of Set 7 | lorengau
# Processing Record 22 of Set 7 | marcona
# City not found. Skipping...
# Processing Record 23 of Set 7 | erenhot
# Processing Record 24 of Set 7 | asau
# Processing Record 25 of Set 7 | broken hill
# Processing Record 26 of Set 7 | opobo
# City not found. Skipping...
# Processing Record 27 of Set 7 | viedma
# Processing Record 28 of Set 7 | aripuana
# Processing Record 29 of Set 7 | kiama
# Processing Record 30 of Set 7 | klyuchi
# Processing Record 31 of Set 7 | leningradskiy
# Processing Record 32 of Set 7 | halifax
# Processing Record 33 of Set 7 | road town
# Processing Record 34 of Set 7 | fevralsk
# City not found. Skipping...
# Processing Record 35 of Set 7 | yumen
# Processing Record 36 of Set 7 | axim
# Processing Record 37 of Set 7 | isangel
# Processing Record 38 of Set 7 | alexandria
# Processing Record 39 of Set 7 | camacha
# Processing Record 40 of Set 7 | gobabis
# Processing Record 41 of Set 7 | champasak
# Processing Record 42 of Set 7 | berlevag
# Processing Record 43 of Set 7 | chuy
# Processing Record 44 of Set 7 | mys shmidta
# City not found. Skipping...
# Processing Record 45 of Set 7 | katangli
# Processing Record 46 of Set 7 | mae sai
# Processing Record 47 of Set 7 | gashua
# Processing Record 48 of Set 7 | koslan
# Processing Record 49 of Set 7 | saint simons
# Processing Record 50 of Set 7 | sayyan
# Processing Record 1 of Set 8 | severo-kurilsk
# Processing Record 2 of Set 8 | beloha
# Processing Record 3 of Set 8 | kropotkin
# Processing Record 4 of Set 8 | ozernovskiy
# Processing Record 5 of Set 8 | sechura
# Processing Record 6 of Set 8 | bethel
# Processing Record 7 of Set 8 | tyukhtet
# Processing Record 8 of Set 8 | pisco
# Processing Record 9 of Set 8 | tessalit
# Processing Record 10 of Set 8 | pangnirtung
# Processing Record 11 of Set 8 | tsihombe
# City not found. Skipping...
# Processing Record 12 of Set 8 | hegang
# Processing Record 13 of Set 8 | west wendover
# Processing Record 14 of Set 8 | khatanga
# Processing Record 15 of Set 8 | tautira
# Processing Record 16 of Set 8 | boden
# Processing Record 17 of Set 8 | odweyne
# Processing Record 18 of Set 8 | kananga
# Processing Record 19 of Set 8 | geraldton
# Processing Record 20 of Set 8 | sao miguel do araguaia
# Processing Record 21 of Set 8 | lac du bonnet
# Processing Record 22 of Set 8 | portales
# Processing Record 23 of Set 8 | lima
# Processing Record 24 of Set 8 | weligama
# Processing Record 25 of Set 8 | malanje
# Processing Record 26 of Set 8 | iqaluit
# Processing Record 27 of Set 8 | durazno
# Processing Record 28 of Set 8 | rybnaya sloboda
# Processing Record 29 of Set 8 | rembang
# Processing Record 30 of Set 8 | nizhneyansk
# City not found. Skipping...
# Processing Record 31 of Set 8 | podgorenskiy
# Processing Record 32 of Set 8 | mayumba
# Processing Record 33 of Set 8 | inongo
# Processing Record 34 of Set 8 | kralendijk
# Processing Record 35 of Set 8 | rincon
# Processing Record 36 of Set 8 | broome
# Processing Record 37 of Set 8 | troitskoye
# Processing Record 38 of Set 8 | daru
# Processing Record 39 of Set 8 | ygatimi
# Processing Record 40 of Set 8 | grand centre
# City not found. Skipping...
# Processing Record 41 of Set 8 | torbay
# Processing Record 42 of Set 8 | saldanha
# Processing Record 43 of Set 8 | roma
# Processing Record 44 of Set 8 | chokurdakh
# Processing Record 45 of Set 8 | verkhniye sergi
# Processing Record 46 of Set 8 | half moon bay
# Processing Record 47 of Set 8 | black river
# Processing Record 48 of Set 8 | kuryk
# Processing Record 49 of Set 8 | shingu
# Processing Record 50 of Set 8 | maues
# Processing Record 1 of Set 9 | hualmay
# Processing Record 2 of Set 9 | college
# Processing Record 3 of Set 9 | harer
# Processing Record 4 of Set 9 | vaitupu
# City not found. Skipping...
# Processing Record 5 of Set 9 | caravelas
# Processing Record 6 of Set 9 | mayo
# Processing Record 7 of Set 9 | zmeinogorsk
# Processing Record 8 of Set 9 | khor
# Processing Record 9 of Set 9 | mocambique
# City not found. Skipping...
# Processing Record 10 of Set 9 | dingle
# Processing Record 11 of Set 9 | zaozerne
# Processing Record 12 of Set 9 | vao
# Processing Record 13 of Set 9 | nicoya
# Processing Record 14 of Set 9 | provideniya
# Processing Record 15 of Set 9 | alekseyevsk
# Processing Record 16 of Set 9 | mogadishu
# Processing Record 17 of Set 9 | ust-nera
# Processing Record 18 of Set 9 | barentsburg
# City not found. Skipping...
# Processing Record 19 of Set 9 | ancud
# Processing Record 20 of Set 9 | opuwo
# Processing Record 21 of Set 9 | maun
# Processing Record 22 of Set 9 | port-gentil
# Processing Record 23 of Set 9 | polyarnyy
# Processing Record 24 of Set 9 | namatanai
# Processing Record 25 of Set 9 | orocue
# Processing Record 26 of Set 9 | gasa
# Processing Record 27 of Set 9 | tahe
# Processing Record 28 of Set 9 | contamana
# Processing Record 29 of Set 9 | matagami
# Processing Record 30 of Set 9 | sosnovo-ozerskoye
# Processing Record 31 of Set 9 | yeppoon
# Processing Record 32 of Set 9 | san juan
# Processing Record 33 of Set 9 | vyazma
# Processing Record 34 of Set 9 | carballo
# Processing Record 35 of Set 9 | kalangala
# Processing Record 36 of Set 9 | chitradurga
# Processing Record 37 of Set 9 | praia
# Processing Record 38 of Set 9 | ergani
# Processing Record 39 of Set 9 | takoradi
# Processing Record 40 of Set 9 | fjerritslev
# Processing Record 41 of Set 9 | gao
# Processing Record 42 of Set 9 | bengkulu
# Processing Record 43 of Set 9 | saint anthony
# Processing Record 44 of Set 9 | komsomolskiy
# Processing Record 45 of Set 9 | ostrovnoy
# Processing Record 46 of Set 9 | puerto el triunfo
# Processing Record 47 of Set 9 | lazarev
# Processing Record 48 of Set 9 | lugo
# Processing Record 49 of Set 9 | umm jarr
# City not found. Skipping...
# Processing Record 50 of Set 9 | lolua
# City not found. Skipping...
# Processing Record 1 of Set 10 | teahupoo
# Processing Record 2 of Set 10 | xixiang
# Processing Record 3 of Set 10 | kidal
# Processing Record 4 of Set 10 | mitsamiouli
# Processing Record 5 of Set 10 | nikolsk
# Processing Record 6 of Set 10 | kumylzhenskaya
# Processing Record 7 of Set 10 | diu
# Processing Record 8 of Set 10 | sawtell
# Processing Record 9 of Set 10 | llallagua
# Processing Record 10 of Set 10 | airai
# Processing Record 11 of Set 10 | conakry
# Processing Record 12 of Set 10 | ketchikan
# Processing Record 13 of Set 10 | pindi gheb
# Processing Record 14 of Set 10 | unye
# City not found. Skipping...
# Processing Record 15 of Set 10 | mago
# Processing Record 16 of Set 10 | hamilton
# Processing Record 17 of Set 10 | qianan
# Processing Record 18 of Set 10 | jabinyanah
# Processing Record 19 of Set 10 | sandovo
# Processing Record 20 of Set 10 | waddan
# Processing Record 21 of Set 10 | chester
# Processing Record 22 of Set 10 | den helder
# Processing Record 23 of Set 10 | tabas
# Processing Record 24 of Set 10 | ixhuatan
# Processing Record 25 of Set 10 | manzil jamil
# City not found. Skipping...
# Processing Record 26 of Set 10 | los llanos de aridane
# Processing Record 27 of Set 10 | champerico
# Processing Record 28 of Set 10 | viligili
# City not found. Skipping...
# Processing Record 29 of Set 10 | lethem
# Processing Record 30 of Set 10 | san policarpo
# Processing Record 31 of Set 10 | bata
# Processing Record 32 of Set 10 | borogontsy
# Processing Record 33 of Set 10 | fort-shevchenko
# Processing Record 34 of Set 10 | khanskaya
# Processing Record 35 of Set 10 | eyl
# Processing Record 36 of Set 10 | souillac
# Processing Record 37 of Set 10 | minudasht
# Processing Record 38 of Set 10 | mantua
# Processing Record 39 of Set 10 | xiuyan
# Processing Record 40 of Set 10 | gat
# Processing Record 41 of Set 10 | caceres
# Processing Record 42 of Set 10 | louisbourg
# City not found. Skipping...
# Processing Record 43 of Set 10 | arandis
# Processing Record 44 of Set 10 | sinnamary
# Processing Record 45 of Set 10 | kytlym
# City not found. Skipping...
# Processing Record 46 of Set 10 | ballina
# Processing Record 47 of Set 10 | malyn
# Processing Record 48 of Set 10 | roebourne
# Processing Record 49 of Set 10 | kurilsk
# Processing Record 50 of Set 10 | puerto madryn
# Processing Record 1 of Set 11 | najran
# Processing Record 2 of Set 11 | bull savanna
# Processing Record 3 of Set 11 | fremont
# Processing Record 4 of Set 11 | zaoyang
# Processing Record 5 of Set 11 | yanan
# City not found. Skipping...
# Processing Record 6 of Set 11 | dagup
# Processing Record 7 of Set 11 | siguiri
# Processing Record 8 of Set 11 | kupang
# Processing Record 9 of Set 11 | acarau
# Processing Record 10 of Set 11 | piney green
# Processing Record 11 of Set 11 | sora
# Processing Record 12 of Set 11 | san cristobal
# Processing Record 13 of Set 11 | macapa
# Processing Record 14 of Set 11 | arona
# Processing Record 15 of Set 11 | baglung
# Processing Record 16 of Set 11 | kerteh
# City not found. Skipping...
# Processing Record 17 of Set 11 | rio gallegos
# Processing Record 18 of Set 11 | zhangjiakou
# Processing Record 19 of Set 11 | kahului
# Processing Record 20 of Set 11 | mundo nuevo
# Processing Record 21 of Set 11 | agadez
# Processing Record 22 of Set 11 | winneba
# Processing Record 23 of Set 11 | pochutla
# Processing Record 24 of Set 11 | mombetsu
# Processing Record 25 of Set 11 | kizema
# Processing Record 26 of Set 11 | naranjal
# Processing Record 27 of Set 11 | nanortalik
# Processing Record 28 of Set 11 | coquimbo
# Processing Record 29 of Set 11 | pacific grove
# Processing Record 30 of Set 11 | sisimiut
# Processing Record 31 of Set 11 | sydney
# Processing Record 32 of Set 11 | opunake
# Processing Record 33 of Set 11 | nhulunbuy
# Processing Record 34 of Set 11 | maku
# Processing Record 35 of Set 11 | bolonchen
# City not found. Skipping...
# Processing Record 36 of Set 11 | halvad
# Processing Record 37 of Set 11 | wuwei
# Processing Record 38 of Set 11 | deqing
# Processing Record 39 of Set 11 | bantogon
# Processing Record 40 of Set 11 | hambantota
# Processing Record 41 of Set 11 | isilkul
# Processing Record 42 of Set 11 | manzil salim
# Processing Record 43 of Set 11 | buritis
# Processing Record 44 of Set 11 | kavaratti
# Processing Record 45 of Set 11 | ixtapa
# Processing Record 46 of Set 11 | cap malheureux
# Processing Record 47 of Set 11 | yekaterinoslavka
# Processing Record 48 of Set 11 | griffith
# Processing Record 49 of Set 11 | morgan city
# Processing Record 50 of Set 11 | touros
# Processing Record 1 of Set 12 | shalinskoye
# Processing Record 2 of Set 12 | coihaique
# Processing Record 3 of Set 12 | ocosingo
# Processing Record 4 of Set 12 | peniche
# Processing Record 5 of Set 12 | turinskaya sloboda
# Processing Record 6 of Set 12 | golpayegan
# Processing Record 7 of Set 12 | rusape
# Processing Record 8 of Set 12 | okha
# Processing Record 9 of Set 12 | karasjok
# Processing Record 10 of Set 12 | fairbanks
# Processing Record 11 of Set 12 | yar-sale
# Processing Record 12 of Set 12 | grindavik
# Processing Record 13 of Set 12 | naumburg
# Processing Record 14 of Set 12 | ginda
# Processing Record 15 of Set 12 | paracuru
# Processing Record 16 of Set 12 | russell
# Processing Record 17 of Set 12 | tucuman
# Processing Record 18 of Set 12 | sri aman
# Processing Record 19 of Set 12 | wembley
# Processing Record 20 of Set 12 | shakawe
# Processing Record 21 of Set 12 | caernarfon
# Processing Record 22 of Set 12 | mujiayingzi
# Processing Record 23 of Set 12 | at-bashi
# Processing Record 24 of Set 12 | gazli
# Processing Record 25 of Set 12 | jining
# Processing Record 26 of Set 12 | killybegs
# Processing Record 27 of Set 12 | atar
# Processing Record 28 of Set 12 | keti bandar
# Processing Record 29 of Set 12 | mbandaka
# Processing Record 30 of Set 12 | samarkand
# Processing Record 31 of Set 12 | jitra
# Processing Record 32 of Set 12 | alofi
# Processing Record 33 of Set 12 | soyo
# Processing Record 34 of Set 12 | nakamura
# Processing Record 35 of Set 12 | samarinda
# Processing Record 36 of Set 12 | mattru
# Processing Record 37 of Set 12 | buluang
# Processing Record 38 of Set 12 | angoche
# Processing Record 39 of Set 12 | hokitika
# Processing Record 40 of Set 12 | xiaoshi
# Processing Record 41 of Set 12 | quchan
# Processing Record 42 of Set 12 | khorramabad
# Processing Record 43 of Set 12 | carlibaba
# Processing Record 44 of Set 12 | anadyr
# Processing Record 45 of Set 12 | mezen
# Processing Record 46 of Set 12 | seydi
# Processing Record 47 of Set 12 | marathopolis
# City not found. Skipping...
# Processing Record 48 of Set 12 | marrakesh
# Processing Record 49 of Set 12 | antonovo
# Processing Record 50 of Set 12 | mocuba
# Processing Record 1 of Set 13 | makuyuni
# Processing Record 2 of Set 13 | naze
# Processing Record 3 of Set 13 | anchorage
# Processing Record 4 of Set 13 | kadykchan
# City not found. Skipping...
# Processing Record 5 of Set 13 | sibolga
# Processing Record 6 of Set 13 | bone
# Processing Record 7 of Set 13 | villiers
# Processing Record 8 of Set 13 | magway
# Processing Record 9 of Set 13 | meulaboh
# Processing Record 10 of Set 13 | mwene-ditu
# Processing Record 11 of Set 13 | la asuncion
# Processing Record 12 of Set 13 | rolla
# Processing Record 13 of Set 13 | trairi
# Processing Record 14 of Set 13 | severo-yeniseyskiy
# Processing Record 15 of Set 13 | kirksville
# Processing Record 16 of Set 13 | havelock
# Processing Record 17 of Set 13 | vestmanna
# Processing Record 18 of Set 13 | jizan
# Processing Record 19 of Set 13 | serebryansk
# Processing Record 20 of Set 13 | damietta
# Processing Record 21 of Set 13 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 22 of Set 13 | limbang
# Processing Record 23 of Set 13 | revda
# Processing Record 24 of Set 13 | henzada
# City not found. Skipping...
# Processing Record 25 of Set 13 | valparaiso
# Processing Record 26 of Set 13 | ous
# Processing Record 27 of Set 13 | llanes
# Processing Record 28 of Set 13 | kromy
# Processing Record 29 of Set 13 | karkaralinsk
# City not found. Skipping...
# Processing Record 30 of Set 13 | luanda
# Processing Record 31 of Set 13 | richards bay
# Processing Record 32 of Set 13 | machali
# Processing Record 33 of Set 13 | boende
# Processing Record 34 of Set 13 | yiyang
# Processing Record 35 of Set 13 | san quintin
# Processing Record 36 of Set 13 | ferme-neuve
# Processing Record 37 of Set 13 | aykhal
# Processing Record 38 of Set 13 | skjervoy
# Processing Record 39 of Set 13 | kununurra
# Processing Record 40 of Set 13 | kerema
# Processing Record 41 of Set 13 | valley city
# Processing Record 42 of Set 13 | oriximina
# Processing Record 43 of Set 13 | mpongwe
# Processing Record 44 of Set 13 | scottsburgh
# City not found. Skipping...
# Processing Record 45 of Set 13 | la romana
# Processing Record 46 of Set 13 | maceio
# Processing Record 47 of Set 13 | morehead
# Processing Record 48 of Set 13 | iwanai
# Processing Record 49 of Set 13 | buin
# Processing Record 50 of Set 13 | chagda
# City not found. Skipping...
# Processing Record 1 of Set 14 | cazaje
# City not found. Skipping...
# Processing Record 2 of Set 14 | tarancon
# Processing Record 3 of Set 14 | arlit
# Processing Record 4 of Set 14 | pundaguitan
# Processing Record 5 of Set 14 | svay rieng
# Processing Record 6 of Set 14 | chernyshevskiy
# Processing Record 7 of Set 14 | katete
# Processing Record 8 of Set 14 | muravlenko
# Processing Record 9 of Set 14 | yasnyy
# Processing Record 10 of Set 14 | snezhnogorsk
# Processing Record 11 of Set 14 | wanxian
# Processing Record 12 of Set 14 | tilichiki
# Processing Record 13 of Set 14 | kushima
# Processing Record 14 of Set 14 | tabiauea
# City not found. Skipping...
# Processing Record 15 of Set 14 | lazaro cardenas
# Processing Record 16 of Set 14 | garowe
# Processing Record 17 of Set 14 | palmer
# Processing Record 18 of Set 14 | madison
# Processing Record 19 of Set 14 | bluefields
# Processing Record 20 of Set 14 | cervo
# Processing Record 21 of Set 14 | port-de-paix
# City not found. Skipping...
# Processing Record 22 of Set 14 | paciran
# Processing Record 23 of Set 14 | rodino
# Processing Record 24 of Set 14 | padang
# Processing Record 25 of Set 14 | skagastrond
# City not found. Skipping...
# Processing Record 26 of Set 14 | kabinda
# Processing Record 27 of Set 14 | wajima
# Processing Record 28 of Set 14 | petropavlovsk-kamchatskiy
# Processing Record 29 of Set 14 | osmena
# Processing Record 30 of Set 14 | samana
# Processing Record 31 of Set 14 | balasheyka
# Processing Record 32 of Set 14 | sovetskiy
# Processing Record 33 of Set 14 | krasnogorsk
# Processing Record 34 of Set 14 | cheuskiny
# City not found. Skipping...
# Processing Record 35 of Set 14 | tommot
# Processing Record 36 of Set 14 | bathsheba
# Processing Record 37 of Set 14 | kolondieba
# Processing Record 38 of Set 14 | kasongo-lunda
# Processing Record 39 of Set 14 | praia da vitoria
# Processing Record 40 of Set 14 | paveh
# Processing Record 41 of Set 14 | isla mujeres
# Processing Record 42 of Set 14 | kenai
# Processing Record 43 of Set 14 | rawannawi
# City not found. Skipping...
# Processing Record 44 of Set 14 | inzai
# Processing Record 45 of Set 14 | cerritos
# Processing Record 46 of Set 14 | san felipe
# Processing Record 47 of Set 14 | muroto
# Processing Record 48 of Set 14 | varhaug
# Processing Record 49 of Set 14 | sobolevo
# Processing Record 50 of Set 14 | verkhnyaya sinyachikha
# Processing Record 1 of Set 15 | nyurba
# Processing Record 2 of Set 15 | alenquer
# Processing Record 3 of Set 15 | laguna
# Processing Record 4 of Set 15 | srednekolymsk
# Processing Record 5 of Set 15 | algiers
# Processing Record 6 of Set 15 | kazalinsk
# City not found. Skipping...
# Processing Record 7 of Set 15 | skibbereen
# Processing Record 8 of Set 15 | pingdu
# Processing Record 9 of Set 15 | spetsai
# City not found. Skipping...
# Processing Record 10 of Set 15 | bontang
# Processing Record 11 of Set 15 | soe
# Processing Record 12 of Set 15 | tadine
# Processing Record 13 of Set 15 | angoram
# Processing Record 14 of Set 15 | poum
# Processing Record 15 of Set 15 | dubbo
# Processing Record 16 of Set 15 | borovskoy
# Processing Record 17 of Set 15 | fuxin
# Processing Record 18 of Set 15 | nishihara
# Processing Record 19 of Set 15 | englehart
# Processing Record 20 of Set 15 | sheopur
# Processing Record 21 of Set 15 | afrikanda
# Processing Record 22 of Set 15 | lucea
# Processing Record 23 of Set 15 | garchitorena
# Processing Record 24 of Set 15 | juybar
# Processing Record 25 of Set 15 | oxchuc
# Processing Record 26 of Set 15 | waraseoni
# Processing Record 27 of Set 15 | la seyne-sur-mer
# Processing Record 28 of Set 15 | mastic beach
# Processing Record 29 of Set 15 | grand gaube
# Processing Record 30 of Set 15 | abu dhabi
# Processing Record 31 of Set 15 | yuzhno-yeniseyskiy
# City not found. Skipping...
# Processing Record 32 of Set 15 | forbes
# Processing Record 33 of Set 15 | riyadh
# Processing Record 34 of Set 15 | batagay-alyta
# Processing Record 35 of Set 15 | edd
# Processing Record 36 of Set 15 | tomohon
# Processing Record 37 of Set 15 | nuuk
# Processing Record 38 of Set 15 | sorvag
# City not found. Skipping...
# Processing Record 39 of Set 15 | werda
# Processing Record 40 of Set 15 | umm lajj
# Processing Record 41 of Set 15 | mountain home
# Processing Record 42 of Set 15 | kawalu
# Processing Record 43 of Set 15 | rikitea
# Processing Record 44 of Set 15 | hasaki
# Processing Record 45 of Set 15 | albany
# Processing Record 46 of Set 15 | bela
# Processing Record 47 of Set 15 | avarua
# Processing Record 48 of Set 15 | san francisco
# Processing Record 49 of Set 15 | acari
# Processing Record 50 of Set 15 | ushuaia
# Processing Record 51 of Set 15 | saskylakh
# Processing Record 52 of Set 15 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 53 of Set 15 | boa vista
# Processing Record 54 of Set 15 | zyryanka
# Processing Record 55 of Set 15 | miandrivazo
# Processing Record 56 of Set 15 | qaanaaq
# Processing Record 57 of Set 15 | canby
# Processing Record 58 of Set 15 | upernavik
# Processing Record 59 of Set 15 | cape town
# Processing Record 60 of Set 15 | tuktoyaktuk
# Processing Record 61 of Set 15 | noyabrsk
# Processing Record 62 of Set 15 | la gaulette
# City not found. Skipping...
# Processing Record 63 of Set 15 | port alfred
# Processing Record 64 of Set 15 | itaituba
# Processing Record 65 of Set 15 | sao filipe
# Processing Record 66 of Set 15 | sirajganj
# Processing Record 67 of Set 15 | olafsvik
# Processing Record 68 of Set 15 | puerto baquerizo moreno
# Processing Record 69 of Set 15 | kerchevskiy
# Processing Record 70 of Set 15 | yining
# Processing Record 71 of Set 15 | punta arenas
# Processing Record 72 of Set 15 | busselton
# Processing Record 73 of Set 15 | imisli
# City not found. Skipping...
# Processing Record 74 of Set 15 | mataura
# Processing Record 75 of Set 15 | hermanus
# Processing Record 76 of Set 15 | bluff
# Processing Record 77 of Set 15 | mehamn
# Processing Record 78 of Set 15 | amderma
# City not found. Skipping...
# Processing Record 79 of Set 15 | butaritari
# Processing Record 80 of Set 15 | auki
# Processing Record 81 of Set 15 | hithadhoo
# Processing Record 82 of Set 15 | kaili
# Processing Record 83 of Set 15 | nikolskoye
# Processing Record 84 of Set 15 | labuhan
# Processing Record 85 of Set 15 | jamestown
# Processing Record 86 of Set 15 | rafraf
# Processing Record 87 of Set 15 | heinola
# Processing Record 88 of Set 15 | rosario
# Processing Record 89 of Set 15 | hilo
# Processing Record 90 of Set 15 | geresk
# City not found. Skipping...
# Processing Record 91 of Set 15 | tanabe
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/lh/b41zj8m157b89wb32ykjqsbm0000gn/T/ipykernel_22623/3093330347.py in <module>
#      28             set_count += 1
#      29             record_count = 1
# ---> 30             time.sleep(60)
#      31
#      32         # Create endpoint URL with each city.
#
# KeyboardInterrupt:

# %%
len(city_data)
# Out:
# 720

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#             City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         Kawalu  -7.3817  108.2082     69.98        91          89
# 1        Rikitea -23.1203 -134.9692     72.75        80         100
# 2         Hasaki  35.7333  140.8333     81.00        85         100
# 3         Albany  42.6001  -73.9662     93.94        52          67
# 4           Bela  25.9333   81.9833     85.21        70          91
# 5         Avarua -21.2078 -159.7750     77.05        65          40
# 6  San Francisco  37.7749 -122.4194     86.50        70          20
# 7          Acari -15.4311  -74.6158     69.06        61          33
# 8        Ushuaia -54.8000  -68.3000     40.66        52          20
# 9      Saskylakh  71.9167  114.0833     53.37        83          89
#
#    Wind Speed Country                 Date
# 0        1.05      ID  2022-08-08 20:53:20
# 1       25.03      PF  2022-08-08 20:53:20
# 2       20.27      JP  2022-08-08 20:53:20
# 3        1.01      US  2022-08-08 20:48:36
# 4        7.78      IN  2022-08-08 20:53:20
# 5       21.85      CK  2022-08-08 20:53:21
# 6       17.27      US  2022-08-08 20:49:49
# 7        8.72      PE  2022-08-08 20:53:21
# 8       10.36      AR  2022-08-08 20:49:56
# 9        9.44      RU  2022-08-08 20:53:22

# %%
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed"]

# %%
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#             City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         Kawalu      ID  -7.3817  108.2082     69.98        91          89
# 1        Rikitea      PF -23.1203 -134.9692     72.75        80         100
# 2         Hasaki      JP  35.7333  140.8333     81.00        85         100
# 3         Albany      US  42.6001  -73.9662     93.94        52          67
# 4           Bela      IN  25.9333   81.9833     85.21        70          91
# 5         Avarua      CK -21.2078 -159.7750     77.05        65          40
# 6  San Francisco      US  37.7749 -122.4194     86.50        70          20
# 7          Acari      PE -15.4311  -74.6158     69.06        61          33
# 8        Ushuaia      AR -54.8000  -68.3000     40.66        52          20
# 9      Saskylakh      RU  71.9167  114.0833     53.37        83          89
#
#    Wind Speed
# 0        1.05
# 1       25.03
# 2       20.27
# 3        1.01
# 4        7.78
# 5       21.85
# 6       17.27
# 7        8.72
# 8       10.36
# 9        9.44

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
